# %% [markdown]
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
# from skimage.io import imread
# from skimage import img_as_ubyte

# %% [markdown]
# See more info at https://www.pyimagesearch.com/2016/03/28/measuring-size-of-objects-in-an-image-with-opencv/

# %%
image = cv2.imread('DSCF2342.JPG')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray = cv2.GaussianBlur(gray, (7, 7), 0)
plt.imshow(image, cmap=plt.cm.gray)
plt.show()

# %%
edged = cv2.Canny(gray, 20, 250)
edged = cv2.dilate(edged, None, iterations=1)
edged = cv2.erode(edged, None, iterations=1)

# %%
plt.imshow(edged)
plt.show()

# %%
cnts = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, 
                        cv2.CHAIN_APPROX_SIMPLE)

# %%
area = []
for i in cnts:
    area.append(cv2.contourArea(i))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-218-6161704b9301> in <module>()
#       1 area = []
#       2 for i in cnts:
# ----> 3     area.append(cv2.contourArea(i))
#
# error: /io/opencv/modules/imgproc/src/shapedescr.cpp:320: error: (-215) npoints >= 0 && (depth == CV_32F || depth == CV_32S) in function contourArea

# %%
from imutils import perspective
from imutils import contours
cnts = cnts[0] if imutils.is_cv2() else cnts[1]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-220-b9bbc23f6c5d> in <module>()
# ----> 1 from imutils import perspective
#       2 from imutils import contours
#       3 cnts = cnts[0] if imutils.is_cv2() else cnts[1]
#
# ImportError: No module named 'imutils'
